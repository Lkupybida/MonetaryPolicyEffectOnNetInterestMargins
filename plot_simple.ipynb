# %%
from plotting_funcs import *
from extraction import *

# %%
plot_IR('data/extracted/PR.csv')

# %%
plot_total('data/extracted/2018_to_now_monthly/NII.csv')

# %%
plot_total('data/extracted/2018_to_now_quaterly/NII.csv')

# %%
plot_total('data/extracted/2018_to_now_quaterly/TA.csv')

# %%
# Load total_income.csv and total_assets.csv
df_net_interest_income = pd.read_csv('data/extracted/2018_to_now_quaterly/NII.csv', index_col=0)
df_assets = pd.read_csv('data/extracted/2018_to_now_quaterly/TA.csv', index_col=0)

# Calculate the ratio of income to assets for each bank
ratio_df = (df_net_interest_income.mean(axis=1) / df_assets.mean(axis=1))

# Plotting
plt.figure(figsize=(14, 8))

plt.plot(pd.to_datetime(ratio_df.index), ratio_df)

plt.title('NIM')
plt.xlabel('Date')
plt.ylabel('NIM')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
